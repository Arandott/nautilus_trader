# %%
# read /home/ubuntu/nautilus_trader/factorexp_live_trading/data/live/b73c3c19-9236-4036-aa45-93ecb604d81b/crypto_perpetual_1755938559393846627.feather
import pandas as pd


df = pd.read_feather("/home/ubuntu/nautilus_trader/factorexp_live_trading/data/live/b9c8fbf1-f7e1-4d66-a707-ea0d0b6b6ab5/crypto_perpetual_1755945648608537100.feather")
print(df)
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[1], line 4
#       1 # read /home/ubuntu/nautilus_trader/factorexp_live_trading/data/live/b73c3c19-9236-4036-aa45-93ecb604d81b/crypto_perpetual_1755938559393846627.feather
#       2 import pandas as pd
# ----> 4 df = pd.read_feather('/home/ubuntu/nautilus_trader/factorexp_live_trading/data/live/b73c3c19-9236-4036-aa45-93ecb604d81b/crypto_perpetual_1755938559393846627.feather')
#       5 print(df)
#
# File ~/nautilus_trader/.venv/lib/python3.12/site-packages/pandas/io/feather_format.py:123, in read_feather(path, columns, use_threads, storage_options, dtype_backend)
#     119 with get_handle(
#     120     path, "rb", storage_options=storage_options, is_text=False
#     121 ) as handles:
#     122     if dtype_backend is lib.no_default and not using_string_dtype():
# --> 123         return feather.read_feather(
# ...
